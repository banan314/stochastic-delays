# %%
import sys
sys.path.append('../')

# %%
from delay.strategy import *

# %% [markdown]
# $ N=100 $
#
# $ d = 20 $

# %% [markdown]
# $ f_A(x) = \begin{cases}
# 		\frac{N}{2} & \mbox{if } x \in [-\frac{N}{2}, 0] \\
# 		\frac{N}{2}-x & \mbox{if } x \in (0, \frac{N}{2}]
# 	\end{cases} $
#
# $ f_B(x) = \begin{cases}
# 		x+\frac{N}{2} & \mbox{if } x \in [-\frac{N}{2}, 0] \\
# 		\frac{N}{2} & \mbox{if } x \in (0, \frac{N}{2}]
# 	\end{cases}  $

# %%
showNormalFunctions(fA_Hard, fB_Hard, N=100)

# %% [markdown]
# 45° always; problem — jak ustalić N? N=6d
#
# $ k = \frac{N-2d}{2} $
#
# $ f_A(x) = \begin{cases}
# 		k & \mbox{if } x \le d \\
# 		-x + k + d & \mbox{if } x > d
# 	\end{cases} $
#
# $ f_B(x) = \begin{cases}
# 		x + k + d & \mbox{if } x < -d \\
#         k & \mbox{if } x \ge -d
# 	\end{cases}  $

# %%
showIntervalFunctions(fA_Skew45deg, fB_Skew45deg, N=100, d=20)

# %% [markdown]
# ???
#
# $ f_A(x) = \begin{cases}
# 		\frac{N}{2} & \mbox{if } x \le d \\
# 		\frac{N}{2} - x + d & \mbox{if } x > d
# 	\end{cases} $
#
# $ f_B(x) = \begin{cases}
# 		\frac{N}{2}+x+d & \mbox{if } x < -d \\
#         \frac{N}{2} & \mbox{if } x \ge -d
# 	\end{cases}  $

# %%
showIntervalFunctions(fA_HardSkew, fB_HardSkew, N=100, d=20)

# %% [markdown]
# chosen, max=N/2 , min=0
#
# $ f_A(x) = \begin{cases}
# 			\frac{N}{2} & \mbox{if } x \in [-\frac{N}{2}, d] \\
#                 \frac{-\frac{N}{2}x + (\frac{N}{2})^2}{\frac{N}{2}-d} =
#                 \frac{-x+\frac{N}{2}}{1-\frac{2d}{N}} =
#                 \frac{-2Nx+N^2}{2N-4d}
#             & \mbox{if } x \in (d, \frac{N}{2}]
# 		\end{cases} $
#
# $ f_B(x) = \begin{cases}
#                 \frac{\frac{N}{2}x + (\frac{N}{2})^2}{\frac{N}{2}-d} =
#                 \frac{x+\frac{N}{2}}{1-\frac{2d}{N}} =
#                 \frac{2Nx+N^2}{2N-4d}
#             & \mbox{if } x \in [-\frac{N}{2}, -d] \\
# 			\frac{N}{2}	& \mbox{if } x \in (-d, \frac{N}{2}]
# 		\end{cases} $

# %%
showIntervalFunctions(fA_HardSkewTo0, fB_HardSkewTo0, N=100, d=20)

# %% [markdown]
# smooth
#
# $ f_A(x) = \frac{N}{4}\tanh(-\omega(x-d) + 1) $
#
# $ f_B(x) = \frac{N}{4}\tanh(\omega(x+d) + 1) $

# %%
showSmoothFunctions(fA_Smooth, fB_Smooth, N=100, d=20, omega=1)

# %%
showIntervalFunctions(fA_TentWithoutStay, fB_TentWithoutStay, 100, 40, filename='../../draft/img/strategies/tent-without');

# %%
showNormalFunctions(fA_TentWithStay, fB_TentWithStay, 100, filename='../../draft/img/strategies/tent-with');
