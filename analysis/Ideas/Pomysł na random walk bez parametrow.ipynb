# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import math
from delay.delay import *
from delay.strategy import fA_Hard, fB_Hard, showNormalFunctions

# %%
def calc.step(d=20, epsilon=0.01):
    def calculate(r):
        if r < -d:
            return epsilon
        if -d <= r <= d:
            return 0.5
        if d < r:
            return 1-epsilon
    return calculate

# %%
def fA(x):
    return N/2 if 0 <= x <= N/2 else N-x

def fB(x):
    return x if 0 <= x <= N/2 else N/2

def simulate():
    def nextElem(func):
        term = 0 if func == max else N
        rc = calculateValue(previousA, previousB)
        value = -rc if func == max else rc
        return func(x[current] + value, term)
    
    current = len(x)-1
    for _ in range(0, duration):
        previousA, previousB = fA(x[current - tauA]), fB(x[current - tauB])
        
        prob = calculateProbability(previousA - previousB)
        r = random.random()
        if r <= prob:
            nextElement = nextElem(min) # +1
        else:
            nextElement = nextElem(max) # -1
                
        x.append(nextElement)
        current += 1

# %%
N=100
showNormalFunctions(fA_Hard, fB_Hard, N)

# %%
calculateProbability = calc.step()

N = 100
x = np.linspace(-N, N, num=1000)

y = []
for xx in x:
    y.append(calculateProbability(xx))

plt.plot(x, y, label='p(+1)')

plt.legend()
plt.show()

# %%
N = 100
tauA = 0
tauB = 0
x = [N/2] * 20 + [N/2 + 1] 
duration = 1000000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  50.04356711756266

# %%
N = 100
tauA = 20
tauB = 0
x = [N/2] * 20 + [N/2 + 1] 
duration = 1000000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1));
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  46.94491966353323

# %%
N = 100
tauA = 0
tauB = 20
x = [N/2] * 20 + [N/2 + 1] 
duration = 1000000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  53.06450651710534

# %%
calculateProbability = calc.step(d=40, epsilon=0.01)

N = 100
x = np.linspace(-N, N, num=1000)

y = []
for xx in x:
    y.append(calculateProbability(xx))

plt.plot(x, y, label='p(+1)')

plt.legend()
plt.show()

# %%
N = 100
tauA = 0
tauB = 0
x = [N/2] * 20 + [N/2 + 1] 
duration = 1000000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  50.267269560829476

# %%
N = 100
tauA = 20
tauB = 0
x = [N/2] * 20 + [N/2 + 1] 
duration = 1000000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  46.649929416456466

# %%
N = 100
tauA = 0
tauB = 20
x = [N/2] * 20 + [N/2 + 1] 
duration = 1000000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  53.31067323208183

# %%
calculateProbability = calc.step(d=200, epsilon=0.01)

N = 1000
x = np.linspace(-N, N, num=1000)

y = []
for xx in x:
    y.append(calculateProbability(xx))

plt.plot(x, y, label='p(+1)')

plt.legend()
plt.show()

# %%
N = 1000
tauA = 100
tauB = 0
x = [N/2] * 100 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  484.04901277327036

# %%
N = 1000
tauA = 0
tauB = 100
x = [N/2] * 100 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  516.9914833519538

# %%
N = 1000
tauA = 500
tauB = 0
x = [N/2] * 500 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  457.17020705431696

# %%
N = 1000
tauA = 0
tauB = 500
x = [N/2] * 500 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  540.695003751783
