# %%
import random

import matplotlib.pyplot as plt
import numpy as np

import delay.calculator as calc
from delay.strategy import fA_Hard, fB_Hard, showNormalFunctions

# %%
def fA(x):
    return N/2 if 0 <= x <= N/2 else N-x

def fB(x):
    return x if 0 <= x <= N/2 else N/2

def simulate():
    def nextElem(func):
        term = 0 if func == max else N
        rc = calculateValue(previousA, previousB)
        value = -rc if func == max else rc
        return func(x[current] + value, term)
    
    current = len(x)-1
    for _ in range(0, duration):
        previousA, previousB = fA(x[current - tauA]), fB(x[current - tauB])
        
        prob = calculateProbability(previousA - previousB)
        r = random.random()
        if r <= prob:
            nextElement = nextElem(min) # +1
        else:
            nextElement = nextElem(max) # -1
                
        x.append(nextElement)
        current += 1

# %%
showNormalFunctions(fA_Hard, fB_Hard, 100)

# %%
calculateProbability = calc.parametric()

N = 100
x = np.linspace(-N, N, num=1000)

y = []
for xx in x:
    y.append(calculateProbability(xx))

plt.plot(x, y, label='p(+1)')

plt.legend()
plt.show()

# %%
N = 100
tauA = 0
tauB = 0
x = [N/2] * 20 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  50.05229948966073

# %%
N = 100
tauA = 20
tauB = 0
x = [N/2] * 20 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  49.712635338804596

# %%
N = 100
tauA = 0
tauB = 20
x = [N/2] * 20 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  50.339724511089614

# %%
calculateProbability = calc.parametric(pd=0.01, s=0.1, d=40, epsilon=0.01)

N = 100
x = np.linspace(-N, N, num=1000)

y = []
for xx in x:
    y.append(calculateProbability(xx))

plt.plot(x, y, label='p(+1)')

plt.legend()
plt.show()

# %%
N = 100
tauA = 0
tauB = 0
x = [N/2] * 20 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  50.06187564570685

# %%
N = 100
tauA = 20
tauB = 0
x = [N/2] * 20 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  48.147017108372445

# %%
N = 100
tauA = 0
tauB = 20
x = [N/2] * 20 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  52.397512778001165

# %%
calculateProbability = calc.parametric(pd=0.01, s=0.1, d=200, epsilon=0.01)

N = 1000
x = np.linspace(-N, N, num=1000)

y = []
for xx in x:
    y.append(calculateProbability(xx))

plt.plot(x, y, label='p(+1)')

plt.legend()
plt.show()

# %%
N = 1000
tauA = 100
tauB = 0
x = [N/2] * 100 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  497.7853675142931

# %%
N = 1000
tauA = 0
tauB = 100
x = [N/2] * 100 + [N/2 + 1] 
duration = 100000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  501.6565374543515

# %%
N = 1000
tauA = 500
tauB = 0
x = [N/2] * 500 + [N/2 + 1] 
duration = 10000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  492.7697655906504

# %%
N = 1000
tauA = 0
tauB = 500
x = [N/2] * 500 + [N/2 + 1] 
duration = 10000 * N
conv = N

simulate()
            
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14, 4.8))
ax1.plot(x)
(bins, _, _) = ax2.hist(x[100*conv:], bins=np.linspace(0, N, N+1))
print('µ = ', np.mean(x[100*conv:]))
# Out:
# µ =  508.01574516279527
