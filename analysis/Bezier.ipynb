# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import math
from delay.delay import *
import delay.calculator as calc
from delay.strategy import fA_Hard, fB_Hard, showFunctions
from delay.simulation import Simulation, FunctionType

# %%
N = 40
fA = fA_Hard(N)
fB = fB_Hard(N)
showFunctions(fA, fB, N)

# %%
calculateProbability = calc.bezier()

N = 100
x = np.linspace(-N, N, num=201)

y = []
for xx in x:
    y.append(calculateProbability(xx))

plt.plot(x, y, label='p(+1)')

plt.legend()
plt.show()

# %%
simulation = Simulation(FunctionType.HARD, (0, 0), calculateValue, calc.linear(N = 100))
simulation.setN(100)
simulation.setDuration(1000 * 100)

simulation.run()
simulation.info()  
simulation.plot(conv=10)
# Out:
# N=100, τ_A=0, τ_B=0, d=0
# µ =  -0.03918142240987465

# %%
simulation.setTau((20, 0))
simulation.info()
simulation.run()
simulation.plot(conv=10)
# Out:
# N=100, τ_A=20, τ_B=0, d=0
# µ =  0.24236273113783946

# %%
simulation.setTau((0, 20))
simulation.info()
simulation.run()
simulation.plot(conv=10)
# Out:
# N=100, τ_A=0, τ_B=20, d=0
# µ =  0.14674664970056855
