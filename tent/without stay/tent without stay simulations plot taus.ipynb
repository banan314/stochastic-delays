# %%
import sys
sys.path.append("../../")

from fractions import Fraction
from delay.matrix.Solver import *
from delay.matrix.Path import *
from delay.matrix.Matrix import *
from delay.matrix.TentSolverWithoutStay import TentSolverWithoutStay as TentSolver
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../../csv/deterministic/tent/without-taus-d10.csv', sep=',')
taus = df.to_dict('l')['τ']
mus = df.to_dict('l')['µ']

# %%
f = len(mus)
plt.xticks(np.arange(0, 10, step=1))
plt.xlabel('$\\tau$', usetex=True, fontsize=24)
plt.ylabel('µ', fontsize=24)
plt.title('$\mu(\\tau)$ for $d=10$', usetex = True, fontsize = 25)
plt.plot(taus[0:f], mus[0:f], linestyle='--', marker='o')
plt.savefig('../../../draft/img/tent-without/mu_of_taus-d10')
